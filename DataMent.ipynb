# %% [markdown]
# <a href="https://colab.research.google.com/github/DataFutebol/DataFut/blob/main/DataMent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importando

# %%
pip install adjustText
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install highlight_text
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install mplsoccer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 5.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# #Jogadores

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patheffects as path_effects
import matplotlib.font_manager as fm
from highlight_text import fig_text, ax_text
from adjustText import adjust_text
from matplotlib.colors import LinearSegmentedColormap, Normalize
from matplotlib import cm
import scipy.stats as stats


from mplsoccer import Pitch

from PIL import Image
import urllib
import os

# %%
import pandas as pd
import csv

df = pd.read_csv('Players.csv')
df
# Out:
#                Full Name              Team             League  season  Age  \
# 0                   Dudu         Palmeiras  Brazilian Serie A    2023   31
# 1               Paulinho  Atlético Mineiro  Brazilian Serie A    2023   22
# 2                 Hyoran  Atlético Mineiro  Brazilian Serie A    2023   29
# 3          Raphael Veiga         Palmeiras  Brazilian Serie A    2023   27
# 4                  Artur         Palmeiras  Brazilian Serie A    2023   25
# ..                   ...               ...                ...     ...  ...
# 438    Gabriel Carabajal     Vasco da Gama  Brazilian Serie A    2023   32
# 439      Robert Arboleda         São Paulo  Brazilian Serie A    2023   31
# 440  Wellington Paulista   América Mineiro  Brazilian Serie A    2023   40
# 441          Rodriguinho         São Paulo  Brazilian Serie A    2023   19
# 442   Mauricio Kozlinski      Fortaleza EC  Brazilian Serie A    2023   31
#
# ...

# %%
gk = df_plot.sort_values(by = 'xGoTA', ascending = False).head(10)

gk = gk[['Full Name','xGoTA']]
gk
# Out:
#                Full Name   xGoTA
# 332           Léo Jardim  12.608
# 361        Marcos Felipe  11.646
# 360   Matheus Cavichioli  11.092
# 343               Walter  11.054
# 377                Fábio  10.001
# 375               Cássio   9.729
# 281  Gabriel Vasconcelos   9.236
# 380              Keiller   8.166
# 179                Bento   8.001
# 354        Rafael Cabral   7.298

# %% [markdown]
# #Times

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

# %%
import pandas as pd
df = pd.read_csv('Teams.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 38 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   team                                  20 non-null     object
#  1   competition                           20 non-null     object
#  2   season                                20 non-null     int64
#  3   Goals                                 20 non-null     int64
#  4   xG                                    20 non-null     float64
#  5   Shots For                             20 non-null     int64
#  6   Shots On Target ( inc goals )         20 non-null     int64
#  7   Shot accuracy (%)                     20 non-null     float64
#  8   Goal Conversion (%)                   20 non-null     float64
#  9   Goals Conceded                        20 non-null     int64
#  10  xG Against                            20 non-null     float64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patheffects as path_effects
import matplotlib.font_manager as fm
import matplotlib.colors as mcolors
from matplotlib import cm
from highlight_text import fig_text, ax_text
from matplotlib.colors import LinearSegmentedColormap, NoNorm
from matplotlib import cm
import matplotlib.gridspec as gridspec
import numpy as np

from PIL import Image
import urllib
import json
import os

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
df['path'] = df['team'] + '.png'
def getImage(path):
    return OffsetImage(plt.imread(path), zoom=.05, alpha = 1)

# %%
# Set font and background colour
plt.rcParams.update({'font.family':'Avenir'})
bgcol = '#fafafa'

# Create initial plot
fig, ax = plt.subplots(figsize=(6, 4), dpi=120)
fig.set_facecolor(bgcol)
ax.set_facecolor(bgcol)
ax.scatter(df['Shots On Target ( inc goals )'], df['On-Target Shots Conceded'], c=bgcol)

# Change plot spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_color('#ccc8c8')
ax.spines['bottom'].set_color('#ccc8c8')

# Change ticks
plt.tick_params(axis='x', labelsize=12, color='#ccc8c8')
plt.tick_params(axis='y', labelsize=12, color='#ccc8c8')

# Plot badges
def getImage(path):
    return OffsetImage(plt.imread(path), zoom=.30, alpha = 1)

for index, row in df.iterrows():
    ab = AnnotationBbox(getImage(row['path']), (row['Shots On Target ( inc goals )'], row['On-Target Shots Conceded']), frameon=False)
    ax.add_artist(ab)

# Add average lines
plt.hlines(df['On-Target Shots Conceded'].mean(), df['Shots On Target ( inc goals )'].min(), df['Shots On Target ( inc goals )'].max(), color='#c2c1c0')
plt.vlines(df['Shots On Target ( inc goals )'].mean(), df['On-Target Shots Conceded'].min(), df['On-Target Shots Conceded'].max(), color='#c2c1c0')

# Text

## Title & comment
fig.text(.15,.98,'Brasileirão - @DataFutebol',size=20)
fig.text(.15,.93,'Jogo das finalizações', size=12)

plt.ylabel('Chutes no Gol CEDIDOS')
plt.xlabel('Chutes no Gol FEITOS')
# Out:
# Text(0.5, 0, 'Chutes no Gol FEITOS')
# WARNING:matplotlib.font_manager:findfont: Font family 'Avenir' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Avenir' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Avenir' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Avenir' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Avenir' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Avenir' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Avenir' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Avenir' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Avenir' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Avenir' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Avenir' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Avenir' not found.
# ...
